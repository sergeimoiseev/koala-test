# %%
from koala.ExcelCompiler import ExcelCompiler
from koala.Spreadsheet import Spreadsheet

sp = Spreadsheet("basic.xlsx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ef49c1baccd3> in <module>
#       2 from koala.Spreadsheet import Spreadsheet
#       3
# ----> 4 sp = Spreadsheet("basic.xlsx")
#
# ~\anaconda3\envs\uoit\lib\site-packages\koala2-0.0.36-py3.8.egg\koala\Spreadsheet.py in __init__(self, file, ignore_sheets, ignore_hidden, debug)
#
# ~\anaconda3\envs\uoit\lib\site-packages\koala2-0.0.36-py3.8.egg\koala\Spreadsheet.py in gen_graph(self, outputs, inputs)
#
# ~\anaconda3\envs\uoit\lib\site-packages\koala2-0.0.36-py3.8.egg\koala\ast\__init__.py in graph_from_seeds(seeds, cell_source)
#
# ~\anaconda3\envs\uoit\lib\site-packages\koala2-0.0.36-py3.8.egg\koala\ast\__init__.py in cell2code(cell, named_ranges)
#
# ~\anaconda3\envs\uoit\lib\site-packages\koala2-0.0.36-py3.8.egg\koala\ast\astnodes.py in emit(self, ast, context, pointer)
#
# ...
